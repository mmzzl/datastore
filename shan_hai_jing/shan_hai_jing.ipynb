# %%
import pygetwindow as gw
import pyautogui 
current_window = gw.getActiveWindow()
if not current_window:
    print("没有活动窗口")
print(f"窗口标题: {current_window.title}")
all_windows = gw.getAllWindows()
for idx, window in enumerate(all_windows):
    print(f"窗口 {idx}: {window.title}")
# Out:
# 窗口标题: shan_hai_jing.ipynb - datastore - Trae CN
# 窗口 0:
# 窗口 1:
# 窗口 2: Paster - Snipaste
# 窗口 3:
# 窗口 4:
# 窗口 5: shan_hai_jing.ipynb - datastore - Trae CN
# 窗口 6: 山海北荒卷
# 窗口 7: 微信
# 窗口 8: Python 2.7 subprocess 在 Linux 中使用 - 豆包 - 豆包
# 窗口 9: npynote book 扩展名是什么_百度搜索 和另外 4 个页面 - 个人 - Microsoft​ Edge
# 窗口 10: 超级文件搜索
# 窗口 11: datastore - 文件资源管理器
# 窗口 12:
# 窗口 13: 命令提示符
# 窗口 14:
# 窗口 15: 设置
# 窗口 16: 设置
# 窗口 17: 电源选项
# 窗口 18:
# 窗口 19:
# 窗口 20:
# 窗口 21:
# 窗口 22:
# 窗口 23:
# 窗口 24: Windows 输入体验
# 窗口 25: 向日葵远程控制
# 窗口 26: 微信
# 窗口 27: Program Manager
